# %% [markdown]
# # ICPE 638 HW1 - Spring 2023
# ## Exploratory Data Analysis for Consumer Data
#
# **Name:** Juan David Baquero Barrios
#
# **UIN:** 833002446
#
# **Google Colab Link:**  https://colab.research.google.com/drive/1Oc3F4GaQ6gHmr96BpbIEq3M6VhTdn9Hg?usp=sharing
#
# Please follow the examples demonstrated in the class to carry out exploratory data analysis (EDA) for the consumer dataset.
#
#
# Please submit your version of this python notebook in Canvas for grade.
#
#
# In addition to showing the output of the EDA, you will need to include the following:
#
#
# 1. Two questions about the consumer data.
#
#   Any reasonable questions about the consumer data. For instance, will high income consumers buy more? Is the spending score influenced more by the age or annual income?
#
#
# 2. Answers to the questions through the EDA and arguments to support them based on your findings.
#
#
# 3. An executive summary of your findings of no more than 3 paragraphs. Feel free to include extra plots and relevant information supporting your arguments (Optional).

# %% [markdown]
# # Summary of EDA process which was carried out
#
# After downloading de data, and check the basic information of the file I took the following steps:
#
# 1. Firstly, after checking the statistics and the histograms of the 3 variables (age, anual spending and spending score), seems not have relevant outliers which may affect the correlation of the variables, for this reason it was no necessary to clean the data.
# 2. Sencondly, after changing the type of the variable gender from object to category, I plot through seaborn a figure type seaborn, trying to figure out some patterns,and correlations among the variables and categories. It made me noticed that exists different patterns among the age, so I decided to split the data in 3 different ages. a. age < 30 b. 30 >= age < 60 c. age >= 60.
# 3, and also the category between male or female.
# 3. After splitting down the data, it was noticible the improvement of the correlation, in comparison to the first correlation of the all data.
#
#
# ## Description of data analysis
#
# For the analysis, I will indicate the filter of data as:
#
# * a. age < 30, male customer
# * b. age < 30, female customer
# * c. 30 >= age < 60, male customer
# * d. 30 >= age < 60, female custome
# * e. 30 >= age < 60, male customer
# * f. age >= 60, female customer
#
# 1.  Is the spending score influenced more by the age or annual income?
# Ans.
# * a. May exist a direct influence between spending score and the age, however, * does not exist a correlation between spending score and the anual income.
# * b. May exist a direct influence between spending score and the age, however, does not exist a correlation between spending score and the anual income.
# * c. May exists a inverse correlation between spending score and the age, however, does not exist a correlation between spending score and the anual income.
# * d. May exist a inverse correlation between spending score and the age, however,  exists a minimum correlation between spending score and the anual income.
# * e. May exist a direct influence between spending score and the age, however, exist a strong correlation between spending score and the anual income.
# * f. Exists a direct influence between spending score and the age, however, may exist a direct influence between spending score and the anual income.
#
# 2.  Is the annual income related to age and differentiated by gener?
# Ans. There
# * a,b. Although exists a small difference, may exist a direct influence of the annual income and the gender in this age.
# * c,d. Although exists a small difference, may exist minimum inverse influence of the annual income and the gender in this age.
# * e,f. May exist a minimum direct influence on the male gender, on the contrary, may exists a minimum indirect influence for the female gender.
#
# ## Excutive summary
#
# The data corresponds to the information of 200 customers, and gives the information of the anual income and the spending score of each one, and also informs the gender of the customer. The main anual income corresponds to a range between 50 - 70 K$ and the spending score around 35 to 55 for customers in a range of age from 18 to 70 years old.
#
# From the relplot graphic, you may infer a pattern that the spending score tends to decrease over the age of the people, and that the anual income the to increase and mantein steady after the age of 20. Also, the spending score tends to be around 50 from an anual income between 40 - 70 k$. There are no significant patterns that may you describe a behavior, however, splitting down the data with the age helps you to infer some correlations which are not string.
#
# As conclusion, you may infer a direct influence of spending score for an age below 30, a strong correlation of spending score and annual income for an age above 60 years and male gender and a direct influence of the spending score for an age above 60 years. From the rest of information exists a weak correlation, so you may need to recolect more variables to infer more patterns and behaviours.

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/jtao/AdvancedML/main/data/Mall_Customers.csv")

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import numpy as nm

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe().T
# Out:
#                         count    mean        std   min    25%    50%     75%  \
# CustomerID              200.0  100.50  57.879185   1.0  50.75  100.5  150.25
# Age                     200.0   38.85  13.969007  18.0  28.75   36.0   49.00
# Annual Income (k$)      200.0   60.56  26.264721  15.0  41.50   61.5   78.00
# Spending Score (1-100)  200.0   50.20  25.823522   1.0  34.75   50.0   73.00
#
#                           max
# CustomerID              200.0
# Age                      70.0
# Annual Income (k$)      137.0
# Spending Score (1-100)   99.0

# %%
df.dtypes
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
df['Gender'] = df['Gender'].astype("category")

# %%
df.dtypes
# Out:
# CustomerID                   int64
# Gender                    category
# Age                          int64
# Annual Income (k$)           int64
# Spending Score (1-100)       int64
# dtype: object

# %%
sns.relplot(data = df, x='Age', y= 'Spending Score (1-100)', hue='Gender', kind="line")

# %%
sns.relplot(data = df, x='Age', y= 'Annual Income (k$)', hue='Gender', kind="line")

# %%
sns.relplot(data = df, x='Annual Income (k$)', y= 'Spending Score (1-100)', hue='Gender', kind="line")

# %%
df_age_30 = df.query("Age <= 30")

# %%
df_age_30_male = df.query("Age <= 30 & Gender == 'Male'")

# %%
df_age_30_female = df.query("Age <= 30 & Gender == 'Female'")

# %%
df_age_30_60 = df.query("Age > 30 & Age <= 60")

# %%
df_age_30_60_male = df.query("Age > 30 & Age <= 60 & Gender=='Male'")

# %%
df_age_30_60_female = df.query("Age > 30 & Age <= 60 & Gender=='Female'")

# %%
df_age_len_male = df.query("Age > 60 & Gender == 'Male'")

# %%
df_age_len_female = df.query("Age > 60 & Gender == 'Female'")

# %%
df['Gender'].unique()
# Out:
# ['Male', 'Female']
# Categories (2, object): ['Female', 'Male']

# %%
sns.pairplot(data = df[["Age","Annual Income (k$)","Spending Score (1-100)"]])

# %%
sns.pairplot(data = df_age_30[["Age","Annual Income (k$)","Spending Score (1-100)"]])

# %%
sns.pairplot(data = df_age_30_60[["Age","Annual Income (k$)","Spending Score (1-100)"]])

# %%
sns.pairplot(data = df_age_len[["Age","Annual Income (k$)","Spending Score (1-100)"]])

# %%
sns.heatmap(data=df[["Age","Annual Income (k$)","Spending Score (1-100)"]].corr(), annot= True, cmap='coolwarm', linewidths=5, linecolor='black', vmin=0.5,vmax=1,cbar=False)

# %%
sns.heatmap(data=df_age_30_male[["Age","Annual Income (k$)","Spending Score (1-100)"]].corr(), annot= True, cmap='coolwarm', linewidths=5, linecolor='black', vmin=0.5,vmax=1,cbar=False)

# %%
sns.heatmap(data=df_age_30_female[["Age","Annual Income (k$)","Spending Score (1-100)"]].corr(), annot= True, cmap='coolwarm', linewidths=5, linecolor='black', vmin=0.5,vmax=1,cbar=False)

# %%
sns.heatmap(data=df_age_30_60_male[["Age","Annual Income (k$)","Spending Score (1-100)"]].corr(), annot= True, cmap='coolwarm', linewidths=5, linecolor='black', vmin=0.5,vmax=1,cbar=False)

# %%
sns.heatmap(data=df_age_30_60_female[["Age","Annual Income (k$)","Spending Score (1-100)"]].corr(), annot= True, cmap='coolwarm', linewidths=5, linecolor='black', vmin=0.5,vmax=1,cbar=False)

# %%
sns.heatmap(data=df_age_len_male[["Age","Annual Income (k$)","Spending Score (1-100)"]].corr(), annot= True, cmap='coolwarm', linewidths=5, linecolor='black', vmin=0.5,vmax=1,cbar=False)

# %%
sns.heatmap(data=df_age_len_female[["Age","Annual Income (k$)","Spending Score (1-100)"]].corr(), annot= True, cmap='coolwarm', linewidths=5, linecolor='black', vmin=0.5,vmax=1,cbar=False)

# %%
sns.boxplot(data=df, x ='Spending Score (1-100)')

# %%
sns.distplot(df['Spending Score (1-100)'], hist=True, kde=True, color = 'orange')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data=df, x ='Annual Income (k$)')

# %%
sns.distplot(df['Annual Income (k$)'], hist=True, kde=True, color = 'orange')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
